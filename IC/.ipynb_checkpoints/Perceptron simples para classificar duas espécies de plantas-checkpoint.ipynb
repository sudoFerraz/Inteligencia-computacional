# %% [markdown]
# ### Trabalho para disciplina Inteligência Computacional 2018-1

# %%
#Perceptron aplicado a um dataset de flores da espécie iris
# -*- coding: utf-8 -*-
#https://archive.ics.uci.edu/ml/datasets/iris

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from IPython.core.display import display
import seaborn as sns
sns.set()

# %% [markdown]
# #### Explorando o dataset e checando se o problema é linearmente separável

# %%
iris = pd.read_csv('train.csv')
display(iris.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
def plot_histogram_dv(feature,labels):
    plt.figure(figsize=(15,10))
    plt.hist(list(feature[labels=='Iris-setosa']), alpha=0.5, label='Setosa')
    plt.hist(list(feature[labels=='Iris-versicolor']), alpha=0.5, label='Virginica')
    plt.title("Histogram of '{var_name}' by Species".format(var_name=feature.name))
    plt.xlabel("Valor")
    plt.ylabel("Frequencia")
    plt.legend(loc="upper right")
    plt.show()
    
plot_histogram_dv(iris['SepalLengthCm'], iris['Species'])
plot_histogram_dv(iris['SepalWidthCm'], iris['Species'])
plot_histogram_dv(iris['PetalLengthCm'], iris['Species'])
plot_histogram_dv(iris['PetalWidthCm'], iris['Species'])

# %% [markdown]
# ###### Dividindo o dataset em 80% para treino e 20% para testes de performance e métricas de acerto

# %%
#randomizando ordem de linhas no dataframe
iris = iris.sample(frac=1).reset_index(drop=True)

#calculando tamanho do dataset e indice do corte
iris_len = len(iris)
iris_split_size = int(iris_len * 0.8)

#Retirando labels dos datasets para input no perceptron
#iris_train = iris[:iris_split_size].drop(['Species'], axis=1)
#iris_test = iris[iris_split_size:].drop(['Species'], axis=1)    
iris_train = iris[:iris_split_size]
iris_test = iris[iris_split_size:]    




#criando array de labels
labels_train = iris[:iris_split_size]['Species']
labels_test = iris[iris_split_size:]['Species']

display(iris_test.head(5))
display(labels_test.head(5))
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 36  69            6.2           2.2            4.5           1.5
# 37  70            5.6           2.5            3.9           1.1
# 38   8            5.0           3.4            1.5           0.2
# 39  15            5.8           4.0            1.2           0.2
# 40   6            5.4           3.9            1.7           0.4
#
#             Species
# 36  Iris-versicolor
# 37  Iris-versicolor
# 38      Iris-setosa
# 39      Iris-setosa
# 40      Iris-setosa
# 36    Iris-versicolor
# 37    Iris-versicolor
# 38        Iris-setosa
# 39        Iris-setosa
# 40        Iris-setosa
# Name: Species, dtype: object

# %%
iris_labeled_train = iris_train.copy()

print iris_train['Species'][0]


for i in range(0, len(iris_labeled_train)):
    if iris_train['Species'][i] == 'Iris-setosa':
        iris_labeled_train.loc[i, 'label'] = 1
    else:
        iris_labeled_train.loc[i, 'label'] = 0

display(iris_labeled_train.tail(5))
display(iris_labeled_train.columns)
# Out:
# Iris-versicolor
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 31   9            4.4           2.9            1.4           0.2
# 32  14            4.3           3.0            1.1           0.1
# 33  63            6.0           2.2            4.0           1.0
# 34  55            6.5           2.8            4.6           1.5
# 35  20            5.1           3.8            1.5           0.3
#
#             Species  label
# 31      Iris-setosa    1.0
# 32      Iris-setosa    1.0
# 33  Iris-versicolor    0.0
# 34  Iris-versicolor    0.0
# 35      Iris-setosa    1.0
# Index([u'Id', u'SepalLengthCm', u'SepalWidthCm', u'PetalLengthCm',
#        u'PetalWidthCm', u'Species', u'label'],
#       dtype='object')
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 41  66            6.7           3.1            4.4           1.4
# 42   5            5.0           3.6            1.4           0.2
# 43  10            4.9           3.1            1.5           0.1
# 44  71            5.9           3.2            4.8           1.8
# 45  64            6.1           2.9            4.7           1.4
#
#             Species  label
# 41  Iris-versicolor    0.0
# 42      Iris-setosa    1.0
# 43      Iris-setosa    1.0
# 44  Iris-versicolor    0.0
# 45  Iris-versicolor    0.0

# %% [markdown]
# ###### Função sigmóide

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

def sigmoid_p(x):
    return sigmoid(x) * (1-sigmoid(x))

# %% [markdown]
# ###### Criando loop para treino de pesos

# %%
learning_rate = 0.2
costs = []

#pesos e bias aleatório
w1 = np.random.randn()
w2 = np.random.randn()
w3 = np.random.randn()
w4 = np.random.randn()
b = np.random.randn()

#Criando um numpy array apenas com os valores de cada feature
data = iris_labeled_train[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'label']].values
labels = []

#Definindo as labels como 0 ou 1
#Iris-Versicolor = 1
#Iris-Virginica = 0

        
repetitions = 100000

for i in range(0, repetitions):
    #Escolhendo um ponto aleatorio do dataset a cada iteracao
    ri = np.random.randint(len(data))
    point = data[ri]
    
    z = point[0] * w1 + point[1] * w2 + point[2] * w3 + point[3] * w4 +b
    prediction = sigmoid(z)
    target = point[4]
    
    #Funcao de custo
    cost = np.square(prediction - target)
    
    #Derivada da funcao de custo
    dcost_prediction = 2 * (prediction - target)
    
    #Sigmoid_p e a derivada da sigmoid, aplicando ao resultado dos pesos
    dprediction_dz = sigmoid_p(z)
    
    #Dados de input e colocando 1 como valor de bias
    dz_dw1 = point[0]
    dz_dw2 = point[1]
    dz_dw3 = point[2]
    dz_dw4 = point[3]
    dz_db = 1
    
    #A curva da funcao de custo
    dcost_dz = dcost_prediction * dprediction_dz
    
    #As curvas dos pesos e do bias
    dcost_dw1 = dcost_dz * dz_dw1
    dcost_dw2 = dcost_dz * dz_dw2
    dcost_dw3 = dcost_dz * dz_dw3
    dcost_dw4 = dcost_dz * dz_dw4
    dcost_db = dcost_dz * dz_db
    
    #Calculando novos pesos e valor do bias
    w1 = w1 - learning_rate * dcost_dw1
    w2 = w2 - learning_rate * dcost_dw2
    w3 = w3 - learning_rate * dcost_dw3
    w4 = w4 - learning_rate * dcost_dw4
    b = b - learning_rate * dcost_db
    
    
    #Fazendo o gráfico para apresentacao das iteracoes
    if i % 10 == 0:
        cost_sum = 0
        for j in range(len(data)) :
            point = data[ri]
            
            z = point [0] * w1 + point[1] * w2 + point[2] * w3 + point[3] * w4 + b
            prediction = sigmoid(z)
            
            target = point[4]
            cost_sum += np.square(prediction - target)
            
        costs.append(cost_sum/len(data))
    
plt.plot(costs)

# %%
iris_labeled_test = iris_test.copy()

for index, row in iris_labeled_test.iterrows():
    if row['Species'] == 'Iris-setosa':
        iris_labeled_test.loc[index, 'label'] = 1
    else:
        iris_labeled_test.loc[index, 'label'] = 0
        
display(iris_labeled_test.tail(5))
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 41  66            6.7           3.1            4.4           1.4
# 42   5            5.0           3.6            1.4           0.2
# 43  10            4.9           3.1            1.5           0.1
# 44  71            5.9           3.2            4.8           1.8
# 45  64            6.1           2.9            4.7           1.4
#
#             Species  label
# 41  Iris-versicolor    0.0
# 42      Iris-setosa    1.0
# 43      Iris-setosa    1.0
# 44  Iris-versicolor    0.0
# 45  Iris-versicolor    0.0

# %%
data = iris_labeled_test[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'label']].values


        
for i in range(len(data)):
    point = data[i]
    display(point)
    
    z = point[0] * w1 + point[1] * w2 + point[2] * w3 + point[3] * w4 + b
    prediction = sigmoid(z)
    target = point[4]
    
    print("Resposta : {}".format(prediction) + " [+] Label Correta: " + str(point[4]))
# Out:
# array([6.2, 2.2, 4.5, 1.5, 0. ])
# Resposta : 5.99201990858e-05 [+] Label Correta: 0.0
# array([5.6, 2.5, 3.9, 1.1, 0. ])
# Resposta : 0.00179618369752 [+] Label Correta: 0.0
# array([5. , 3.4, 1.5, 0.2, 1. ])
# Resposta : 0.997539767698 [+] Label Correta: 1.0
# array([5.8, 4. , 1.2, 0.2, 1. ])
# Resposta : 0.999890609236 [+] Label Correta: 1.0
# array([5.4, 3.9, 1.7, 0.4, 1. ])
# Resposta : 0.998389176265 [+] Label Correta: 1.0
# array([6.7, 3.1, 4.4, 1.4, 0. ])
# Resposta : 0.00156618903033 [+] Label Correta: 0.0
# array([5. , 3.6, 1.4, 0.2, 1. ])
# Resposta : 0.998970745698 [+] Label Correta: 1.0
# array([4.9, 3.1, 1.5, 0.1, 1. ])
# Resposta : 0.995408439773 [+] Label Correta: 1.0
# array([5.9, 3.2, 4.8, 1.8, 0. ])
# Resposta : 0.000125446332751 [+] Label Correta: 0.0
# array([6.1, 2.9, 4.7, 1.4, 0. ])
# Resposta : 0.000226946866998 [+] Label Correta: 0.0
